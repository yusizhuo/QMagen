# %% [markdown]
# # This a demo for Hamiltonian-Learning on a XXZ heisenberg chain
#
# ![image.png](attachment:image.png)
# ###  $$H = \sum_{\langle i,j \rangle} J_{xy} (S_i^{x} S_j^{x} + S_i^y S_j^y)
# + J_z S_i^z S_j^z$$

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import cm
import parameters
import pandas as pd
from solver_ED import solver_ED
from SubFunc.Calcul_Loss import calcul_loss
from SubFunc.get_T_cut import get_T_cut
from adlib.ThObs import Th_obs
from SubFunc.CalSus_Num import calcul_chi_num
from bayes_opt import BayesianOptimization
from bayes_opt import UtilityFunction

from scipy.interpolate import griddata

# %%
C = np.loadtxt('./Data/C_exp.csv', delimiter=',')
T = np.loadtxt('./Data/T_exp.csv', delimiter=',')
Chixy = np.loadtxt('./Data/Chixy_exp.csv', delimiter=',')
Chiz = np.loadtxt('./Data/Chiz_exp.csv', delimiter=',')



fig, [ax_c, ax_chi] = plt.subplots(1, 2, figsize=[12,4]) 
ax_c.semilogx(T, C, 'o', fillstyle='none', label='C')
ax_chi.semilogx(T, Chixy, 'v', fillstyle='none', label=r'$\chi_{xy}$')
ax_chi.semilogx(T, Chiz, '^', fillstyle='none',label=r'$\chi_{z}$')
ax_c.legend(fontsize=20)
ax_chi.legend(fontsize=20)
print('First look at our experiment data')
# Out:
# First look at our experiment data

# %%
# this is how you solve the system by ED

# Jz = torch.tensor( 0.097179772, requires_grad=True)
# Jxy = torch.tensor(1.5237368651, requires_grad=True)

Jz = torch.tensor(1.5, requires_grad=True)
Jxy = torch.tensor(1., requires_grad=True)

# define the system
params = parameters.params()
params.get_Hamiltonian_params(Jz=Jz, Jxy=Jxy, hz=0, hx=0, d=2)
params.get_system_params(L=10, T=T)

# ED solver
solver = solver_ED(L=8)
obs = solver.forward(params=params)

#numerical calculation of xy-direction susceptibility
calcul_chi_num(obs, params, solver.solver_params, 0.05)

#for convenience
obs_real = Th_obs(params=params)
obs_real.T = torch.tensor(T)
obs_real.C = torch.tensor(C)
obs_real.Chi = torch.tensor(Chiz)
obs_real.Chi_paral = torch.tensor(Chixy)

#let's see how ED fit the experiment
fig.axes[0].semilogx(obs.T, obs.C.detach().numpy(), '--', color='black', label='ED', alpha=0.7)
fig.axes[1].semilogx(obs.T, obs.Chi.detach().numpy(), '--', color='black', label='ED', alpha=0.7)
fig.axes[1].semilogx(obs.T, obs.Chi_paral.detach().numpy(), '--', color='black', label='ED')
fig

# %%
#Now we see it is curcial to first introduce a T_cut to choose the appropriate temperature interval for fitting
T_cut = get_T_cut(['C', 'Chi', 'Chi_paral'], obs_real, params, shift=-5)

fig.axes[0].axvline(obs_real.T[-T_cut['C']], ls='-.', color='black', label=r'$T_{cut}$')
fig.axes[1].axvline(obs_real.T[-T_cut['Chi']], ls='-.', color='black', label=r'$T_{cut}$')
fig

# %% [markdown]
# ## Bayesian Optimization
#
# Suppose the true parameter is unknown. We can define a loss function as follows
#
# $$\mathcal{L} = \sum_{\alpha}\frac{1}{N_\alpha} \lambda_{\alpha}(\frac{O^{\rm expr}_\alpha-O^{\rm theor}_\alpha}{O^{\rm theor}_\alpha})^2$$
#
# Bayesian Optimization (BO) is a powerful tool solving the following problem $$\arg \min_{\mathbf{x}} \mathcal{L}(\mathbf{x})$$

# %%
num_warmup = 10
nexp = 200
aqui_f = 'ei'

target_obs=['C', 'Chi', 'Chi_paral']

epsilon = 0.05
ksi = 0.02

#===========we define the "black box" function to optimize========#
def evaluate_parameter(Jxy, Jz):
    Jz = torch.tensor(Jz, requires_grad=True)
    Jxy = torch.tensor(Jxy, requires_grad=True)
    params = parameters.params()
    params.get_Hamiltonian_params(Jz=Jz, Jxy=Jxy, hz=0, hx=0, d=2)
    params.get_system_params(L=8, T=T)
    solver = solver_ED(L=8)
    obs = solver.forward(params=params)
    calcul_chi_num(obs, params, solver.solver_params, 0.05)
    Loss = calcul_loss(obs_real=obs_real, obs_iter=obs, target_obs=target_obs, T_cut=T_cut).detach().numpy()
    return -np.log10(Loss)

    
pbounds = {'Jxy': (-10., 10.), 'Jz': (-10., 10.)}
optimizer_bayesian = BayesianOptimization(
            f=evaluate_parameter,
            pbounds=pbounds,
            verbose=2,
            random_state=5)
utility = UtilityFunction(kind=aqui_f, kappa=2.5, xi=0.0)

y = np.zeros(nexp)
#Warm up
for i in range(num_warmup):
    next_point = {'Jxy': np.random.rand()*20 - 10 , 'Jz':np.random.rand()*20 - 10}
    target = evaluate_parameter(**next_point)
    y[i] = target
    optimizer_bayesian.register(params=next_point, target=target)
    

    print('Warming up.............{}/{}'.format(i+1, num_warmup))
    print('Found Loss {:.2e} at Jxy = {:.2f}, Jz = {:.2f}'.format(-target, next_point['Jxy'], next_point['Jz']))

#BO with e-greedy strategy
for _ in range(nexp - num_warmup):
    x = np.random.random()
    if x < 1 - epsilon:
        utility.xi = y[0:_+num_warmup].std() * ksi
        next_point = optimizer_bayesian.suggest(utility)
        target = evaluate_parameter(**next_point)
        y[_ + num_warmup] = target
        optimizer_bayesian.register(params=next_point, target=target)
        print('Greedy..............{}/{}_iter'.format(_ + 1 + num_warmup, nexp))
        print('Found Loss {:.2e} at Jxy = {:.2f}, Jz = {:.2f}'.format(target, next_point['Jxy'], next_point['Jz']))
    else:
        next_point = {'Jxy': np.random.rand()*20 - 10 , 'Jz':np.random.rand()*20 - 10}
        target = evaluate_parameter(**next_point)
        y[_ + num_warmup] = target
        optimizer_bayesian.register(params=next_point, target=target)
        print('Random..............{}/{}_iter'.format(_ + 1 + num_warmup, nexp))
        print('Found Loss {:.2e} at Jxy = {:.2f}, Jz = {:.2f}'.format(target, next_point['Jxy'], next_point['Jz']))



print("=======================COMPLETED=======================\n\n\n")
best = optimizer_bayesian.max
print("Best paramter find at Jxy = {:.2f}, Jz = {:.2f}, with loss = {:.2e}".
      format(best['params']['Jxy'], best['params']['Jz'], best['target']))
# Out:
# Warming up.............1/10
# Found Loss 2.26e+00 at Jxy = 7.05, Jz = -7.56
# Warming up.............2/10
# Found Loss 2.61e+00 at Jxy = 7.02, Jz = -9.04
# Warming up.............3/10
# Found Loss 2.67e+00 at Jxy = -0.03, Jz = -8.48
# Warming up.............4/10
# Found Loss 2.67e+00 at Jxy = 0.12, Jz = -9.40
# Warming up.............5/10
# Found Loss 2.62e+00 at Jxy = -0.28, Jz = -4.85
# Warming up.............6/10
# Found Loss 2.47e+00 at Jxy = 0.68, Jz = -3.11
# Warming up.............7/10
# Found Loss 2.65e+00 at Jxy = -1.69, Jz = -6.79
# Warming up.............8/10
# Found Loss -7.47e-02 at Jxy = 1.93, Jz = 1.96
# Warming up.............9/10
# Found Loss 2.27e+00 at Jxy = -8.54, Jz = -6.68
# Warming up.............10/10
# Found Loss 6.32e-01 at Jxy = 6.58, Jz = 1.16
# Greedy..............11/200_iter
# Found Loss -4.44e-01 at Jxy = 2.50, Jz = 4.02
# Greedy..............12/200_iter
# Found Loss -3.41e-01 at Jxy = 3.24, Jz = 1.79
# Greedy..............13/200_iter
# Found Loss 1.45e-01 at Jxy = 0.29, Jz = 2.55
# Greedy..............14/200_iter
# Found Loss 4.03e-01 at Jxy = 1.00, Jz = 2.33
# Greedy..............15/200_iter
# Found Loss -2.41e-02 at Jxy = 1.22, Jz = 2.90
# Greedy..............16/200_iter
# Found Loss 8.61e-01 at Jxy = 0.71, Jz = 1.61
# Greedy..............17/200_iter
# Found Loss -1.89e-01 at Jxy = 0.41, Jz = 1.06
# Random..............18/200_iter
# Found Loss -7.50e-01 at Jxy = 4.08, Jz = 9.13
# Greedy..............19/200_iter
# Found Loss 1.53e+00 at Jxy = 0.92, Jz = 1.60
# Greedy..............20/200_iter
# Found Loss 1.26e+00 at Jxy = 1.10, Jz = 1.64
# Greedy..............21/200_iter
# Found Loss -7.52e-01 at Jxy = 4.03, Jz = 9.14
# Greedy..............22/200_iter
# Found Loss 1.51e+00 at Jxy = 0.98, Jz = 1.41
# Greedy..............23/200_iter
# Found Loss 1.02e+00 at Jxy = 1.25, Jz = 0.93
# Greedy..............24/200_iter
# Found Loss 3.79e-01 at Jxy = 1.87, Jz = 0.96
# Greedy..............25/200_iter
# Found Loss 1.34e-01 at Jxy = 1.36, Jz = 0.25
# Greedy..............26/200_iter
# Found Loss -2.76e-01 at Jxy = 0.17, Jz = 3.54
# Greedy..............27/200_iter
# Found Loss 1.76e-02 at Jxy = 2.67, Jz = 0.23
# Greedy..............28/200_iter
# Found Loss -3.29e-01 at Jxy = 3.85, Jz = 0.28
# Greedy..............29/200_iter
# Found Loss 1.46e+00 at Jxy = 0.93, Jz = 1.49
# Greedy..............30/200_iter
# Found Loss 8.39e-01 at Jxy = 0.95, Jz = 1.16
# Random..............31/200_iter
# Found Loss -3.14e-01 at Jxy = 1.01, Jz = 3.69
# Greedy..............32/200_iter
# Found Loss 6.23e-01 at Jxy = 1.22, Jz = 1.24
# Greedy..............33/200_iter
# Found Loss 6.14e-01 at Jxy = 0.88, Jz = 1.87
# Greedy..............34/200_iter
# Found Loss 3.62e-01 at Jxy = 1.09, Jz = 0.71
# Greedy..............35/200_iter
# Found Loss -7.69e-01 at Jxy = 5.38, Jz = 9.73
# Greedy..............36/200_iter
# Found Loss -1.32e+00 at Jxy = -9.49, Jz = 4.07
# Greedy..............37/200_iter
# Found Loss 6.24e-01 at Jxy = 1.52, Jz = 0.73
# Greedy..............38/200_iter
# Found Loss -9.86e-02 at Jxy = 2.66, Jz = 1.08
# Greedy..............39/200_iter
# Found Loss 3.38e-01 at Jxy = 2.02, Jz = 0.31
# Random..............40/200_iter
# Found Loss -1.76e+00 at Jxy = -4.46, Jz = 1.44
# Greedy..............41/200_iter
# Found Loss -1.67e+00 at Jxy = 1.57, Jz = -1.90
# Greedy..............42/200_iter
# Found Loss -1.25e+00 at Jxy = -7.84, Jz = 5.13
# Greedy..............43/200_iter
# Found Loss 7.17e-01 at Jxy = 0.87, Jz = 1.84
# Greedy..............44/200_iter
# Found Loss 1.63e+00 at Jxy = 1.01, Jz = 1.58
# Greedy..............45/200_iter
# Found Loss 5.19e-02 at Jxy = 2.05, Jz = -0.32
# Greedy..............46/200_iter
# Found Loss -2.81e-01 at Jxy = -0.13, Jz = 1.96
# Greedy..............47/200_iter
# Found Loss -1.59e-01 at Jxy = 2.08, Jz = 2.68
# Greedy..............48/200_iter
# Found Loss -5.90e-02 at Jxy = 2.97, Jz = -0.72
# Greedy..............49/200_iter
# Found Loss -2.10e-01 at Jxy = 3.78, Jz = -1.28
# Greedy..............50/200_iter
# Found Loss 9.59e-01 at Jxy = 1.03, Jz = 1.47
# Greedy..............51/200_iter
# Found Loss 1.47e+00 at Jxy = 0.94, Jz = 1.68
# Greedy..............52/200_iter
# Found Loss -5.92e-01 at Jxy = 8.81, Jz = -2.72
# Random..............53/200_iter
# Found Loss -6.02e-01 at Jxy = 6.97, Jz = -0.18
# Greedy..............54/200_iter
# Found Loss 6.51e-01 at Jxy = 0.73, Jz = 1.33
# Greedy..............55/200_iter
# Found Loss 8.07e-01 at Jxy = 1.48, Jz = 1.00
# Greedy..............56/200_iter
# Found Loss 6.52e-01 at Jxy = 1.23, Jz = 1.95
# Greedy..............57/200_iter
# Found Loss 2.60e-01 at Jxy = 1.40, Jz = 2.29
# Greedy..............58/200_iter
# Found Loss 4.49e-01 at Jxy = 0.49, Jz = 1.84
# Greedy..............59/200_iter
# Found Loss 4.56e-01 at Jxy = 1.88, Jz = 0.58
# Greedy..............60/200_iter
# Found Loss 2.05e-01 at Jxy = 2.20, Jz = 0.72
# Random..............61/200_iter
# Found Loss -1.77e+00 at Jxy = -1.20, Jz = 0.00
# Greedy..............62/200_iter
# Found Loss -6.75e-01 at Jxy = 6.52, Jz = 2.44
# Greedy..............63/200_iter
# Found Loss -7.39e-01 at Jxy = 7.91, Jz = 3.30
# Random..............64/200_iter
# Found Loss -1.89e+00 at Jxy = 6.24, Jz = -6.32
# Greedy..............65/200_iter
# Found Loss 9.68e-01 at Jxy = 1.01, Jz = 1.28
# Greedy..............66/200_iter
# Found Loss -1.08e+00 at Jxy = -8.65, Jz = 7.05
# Greedy..............67/200_iter
# Found Loss 3.47e-01 at Jxy = 0.61, Jz = 2.26
# Greedy..............68/200_iter
# Found Loss -2.13e+00 at Jxy = -8.43, Jz = -4.21
# Greedy..............69/200_iter
# Found Loss 9.60e-01 at Jxy = 0.93, Jz = 1.39
# Greedy..............70/200_iter
# Found Loss 1.34e+00 at Jxy = 1.01, Jz = 1.72
# Greedy..............71/200_iter
# Found Loss 8.05e-01 at Jxy = 1.02, Jz = 0.98
# Greedy..............72/200_iter
# Found Loss -6.74e-01 at Jxy = 5.30, Jz = 4.07
# Greedy..............73/200_iter
# Found Loss -7.56e-01 at Jxy = 5.22, Jz = 8.21
# Greedy..............74/200_iter
# Found Loss 4.59e-01 at Jxy = 1.30, Jz = 0.81
# Greedy..............75/200_iter
# Found Loss 1.08e+00 at Jxy = 1.33, Jz = 1.04
# Greedy..............76/200_iter
# Found Loss 9.00e-01 at Jxy = 1.22, Jz = 1.73
# Greedy..............77/200_iter
# Found Loss -1.65e+00 at Jxy = -8.71, Jz = 0.79
# Greedy..............78/200_iter
# Found Loss 6.10e-01 at Jxy = 1.69, Jz = 0.85
# Greedy..............79/200_iter
# Found Loss 1.16e+00 at Jxy = 1.10, Jz = 1.64
# Greedy..............80/200_iter
# Found Loss -8.14e-01 at Jxy = 9.63, Jz = 5.94
# Greedy..............81/200_iter
# Found Loss 1.51e+00 at Jxy = 1.02, Jz = 1.64
# Greedy..............82/200_iter
# Found Loss 1.19e+00 at Jxy = 0.97, Jz = 1.63
# Greedy..............83/200_iter
# Found Loss -9.09e-01 at Jxy = -6.34, Jz = 8.26
# Greedy..............84/200_iter
# Found Loss 1.02e+00 at Jxy = 0.78, Jz = 1.61
# Greedy..............85/200_iter
# Found Loss 1.01e+00 at Jxy = 1.11, Jz = 1.80
# Greedy..............86/200_iter
# Found Loss 1.35e+00 at Jxy = 1.05, Jz = 1.67
# Greedy..............87/200_iter
# Found Loss 6.95e-01 at Jxy = 0.83, Jz = 1.67
# Greedy..............88/200_iter
# Found Loss 9.71e-01 at Jxy = 0.83, Jz = 1.48
# Greedy..............89/200_iter
# Found Loss 1.12e+00 at Jxy = 1.14, Jz = 1.71
# Greedy..............90/200_iter
# Found Loss 1.26e+00 at Jxy = 0.94, Jz = 1.75
# Greedy..............91/200_iter
# Found Loss 1.23e+00 at Jxy = 1.16, Jz = 1.14
# Greedy..............92/200_iter
# Found Loss 1.05e+00 at Jxy = 0.98, Jz = 1.54
# Greedy..............93/200_iter
# Found Loss -1.93e+00 at Jxy = -4.90, Jz = 0.10
# Greedy..............94/200_iter
# Found Loss -2.66e+00 at Jxy = 0.82, Jz = -6.90
# Greedy..............95/200_iter
# Found Loss -1.25e+00 at Jxy = -8.77, Jz = 5.04
# Greedy..............96/200_iter
# Found Loss 1.11e+00 at Jxy = 1.34, Jz = 1.14
# Greedy..............97/200_iter
# Found Loss 5.30e-01 at Jxy = 0.64, Jz = 1.47
# Greedy..............98/200_iter
# Found Loss 8.45e-01 at Jxy = 1.07, Jz = 1.40
# Greedy..............99/200_iter
# Found Loss 8.65e-01 at Jxy = 1.13, Jz = 1.08
# Greedy..............100/200_iter
# Found Loss -1.29e+00 at Jxy = -5.80, Jz = 4.66
# Greedy..............101/200_iter
# Found Loss -5.78e-01 at Jxy = 7.25, Jz = -1.12
# Greedy..............102/200_iter
# Found Loss 1.07e+00 at Jxy = 1.23, Jz = 1.12
# Greedy..............103/200_iter
# Found Loss -6.85e-01 at Jxy = 9.84, Jz = -0.87
# Greedy..............104/200_iter
# Found Loss 8.31e-01 at Jxy = 1.44, Jz = 1.11
# Greedy..............105/200_iter
# Found Loss -2.09e+00 at Jxy = -6.83, Jz = -2.51
# Greedy..............106/200_iter
# Found Loss 1.13e+00 at Jxy = 0.86, Jz = 1.62
# Greedy..............107/200_iter
# Found Loss -2.63e+00 at Jxy = -5.36, Jz = -8.10
# Random..............108/200_iter
# Found Loss -5.20e-01 at Jxy = 2.81, Jz = 4.52
# Greedy..............109/200_iter
# Found Loss -6.54e-01 at Jxy = 7.25, Jz = 0.97
# Greedy..............110/200_iter
# Found Loss 9.99e-01 at Jxy = 1.03, Jz = 1.84
# Greedy..............111/200_iter
# Found Loss 6.06e-01 at Jxy = 1.09, Jz = 1.96
# Greedy..............112/200_iter
# Found Loss -1.75e+00 at Jxy = -7.78, Jz = 0.29
# Greedy..............113/200_iter
# Found Loss 3.09e-01 at Jxy = 1.46, Jz = 0.88
# Greedy..............114/200_iter
# Found Loss 6.97e-01 at Jxy = 1.15, Jz = 0.92
# Greedy..............115/200_iter
# Found Loss 6.71e-01 at Jxy = 1.32, Jz = 1.77
# Greedy..............116/200_iter
# Found Loss 5.44e-01 at Jxy = 1.71, Jz = 0.65
# Greedy..............117/200_iter
# Found Loss 1.03e+00 at Jxy = 0.92, Jz = 1.54
# Greedy..............118/200_iter
# Found Loss -5.84e-01 at Jxy = 7.36, Jz = -1.12
# Greedy..............119/200_iter
# Found Loss 1.19e+00 at Jxy = 1.04, Jz = 1.17
# Greedy..............120/200_iter
# Found Loss 6.55e-01 at Jxy = 1.63, Jz = 1.07
# Random..............121/200_iter
# Found Loss -6.21e-01 at Jxy = 6.45, Jz = 0.85
# Greedy..............122/200_iter
# Found Loss -1.58e+00 at Jxy = -6.91, Jz = 2.20
# Greedy..............123/200_iter
# Found Loss 1.41e+00 at Jxy = 1.11, Jz = 1.22
# Greedy..............124/200_iter
# Found Loss 7.70e-01 at Jxy = 1.19, Jz = 1.86
# Greedy..............125/200_iter
# Found Loss -1.39e+00 at Jxy = -9.68, Jz = 3.25
# Random..............126/200_iter
# Found Loss -1.20e+00 at Jxy = -0.64, Jz = 1.14
# Greedy..............127/200_iter
# Found Loss 5.44e-01 at Jxy = 0.89, Jz = 1.03
# Greedy..............128/200_iter
# Found Loss 5.03e-01 at Jxy = 1.81, Jz = 0.78
# Greedy..............129/200_iter
# Found Loss 4.18e-01 at Jxy = 0.90, Jz = 0.84
# Greedy..............130/200_iter
# Found Loss 8.33e-01 at Jxy = 0.67, Jz = 1.78
# Greedy..............131/200_iter
# Found Loss 2.69e-01 at Jxy = 0.46, Jz = 1.63
# Greedy..............132/200_iter
# Found Loss 8.12e-01 at Jxy = 1.48, Jz = 1.24
# Greedy..............133/200_iter
# Found Loss 7.55e-01 at Jxy = 0.73, Jz = 1.95
# Greedy..............134/200_iter
# Found Loss 5.68e-01 at Jxy = 1.64, Jz = 1.22
# Greedy..............135/200_iter
# Found Loss 5.94e-01 at Jxy = 0.80, Jz = 2.19
# Greedy..............136/200_iter
# Found Loss -1.44e+00 at Jxy = -9.20, Jz = 2.77
# Greedy..............137/200_iter
# Found Loss 6.73e-01 at Jxy = 0.98, Jz = 2.12
# Greedy..............138/200_iter
# Found Loss 3.41e-01 at Jxy = 1.44, Jz = 1.96
# Greedy..............139/200_iter
# Found Loss 1.52e+00 at Jxy = 0.95, Jz = 1.46
# Greedy..............140/200_iter
# Found Loss -2.25e+00 at Jxy = -4.86, Jz = -5.28
# Greedy..............141/200_iter
# Found Loss -8.76e-01 at Jxy = -6.10, Jz = 8.47
# Greedy..............142/200_iter
# Found Loss 2.86e-01 at Jxy = 0.67, Jz = 1.12
# Greedy..............143/200_iter
# Found Loss -5.35e-01 at Jxy = 0.77, Jz = 4.75
# Greedy..............144/200_iter
# Found Loss -1.08e+00 at Jxy = -9.89, Jz = 7.20
# Greedy..............145/200_iter
# Found Loss -2.65e+00 at Jxy = 2.68, Jz = -6.99
# Greedy..............146/200_iter
# Found Loss 5.64e-01 at Jxy = 0.58, Jz = 2.09
# Greedy..............147/200_iter
# Found Loss 5.17e-01 at Jxy = 1.59, Jz = 1.40
# Greedy..............148/200_iter
# Found Loss 5.66e-01 at Jxy = 1.45, Jz = 0.52
# Greedy..............149/200_iter
# Found Loss 2.31e-01 at Jxy = 1.59, Jz = 0.59
# Greedy..............150/200_iter
# Found Loss 4.57e-01 at Jxy = 0.61, Jz = 1.95
# Greedy..............151/200_iter
# Found Loss -7.63e-01 at Jxy = 9.88, Jz = 2.53
# Greedy..............152/200_iter
# Found Loss 5.16e-01 at Jxy = 1.17, Jz = 2.16
# Random..............153/200_iter
# Found Loss -1.53e+00 at Jxy = -9.71, Jz = 1.64
# Greedy..............154/200_iter
# Found Loss 5.03e-01 at Jxy = 1.33, Jz = 0.62
# Greedy..............155/200_iter
# Found Loss -2.04e+00 at Jxy = -8.36, Jz = -3.03
# Random..............156/200_iter
# Found Loss -2.49e+00 at Jxy = -5.71, Jz = -6.80
# Greedy..............157/200_iter
# Found Loss 4.26e-01 at Jxy = 1.82, Jz = 1.12
# Greedy..............158/200_iter
# Found Loss 3.54e-01 at Jxy = 0.43, Jz = 2.21
# Greedy..............159/200_iter
# Found Loss 9.30e-01 at Jxy = 1.39, Jz = 1.38
# Greedy..............160/200_iter
# Found Loss 7.67e-01 at Jxy = 1.40, Jz = 1.53
# Greedy..............161/200_iter
# Found Loss 2.29e-01 at Jxy = 1.19, Jz = 2.35
# Greedy..............162/200_iter
# Found Loss 4.79e-01 at Jxy = 1.54, Jz = 1.58
# Greedy..............163/200_iter
# Found Loss 3.01e-01 at Jxy = 1.27, Jz = 0.41
# Greedy..............164/200_iter
# Found Loss 2.51e-01 at Jxy = 2.15, Jz = 0.46
# Greedy..............165/200_iter
# Found Loss 8.47e-01 at Jxy = 0.84, Jz = 2.04
# Greedy..............166/200_iter
# Found Loss 3.48e-01 at Jxy = 1.63, Jz = 1.78
# Greedy..............167/200_iter
# Found Loss 3.66e-01 at Jxy = 1.74, Jz = 0.28
# Greedy..............168/200_iter
# Found Loss 6.91e-01 at Jxy = 1.47, Jz = 1.41
# Greedy..............169/200_iter
# Found Loss -2.53e+00 at Jxy = -3.68, Jz = -5.25
# Greedy..............170/200_iter
# Found Loss 3.39e-01 at Jxy = 0.37, Jz = 2.01
# Greedy..............171/200_iter
# Found Loss 3.63e-01 at Jxy = 1.80, Jz = 1.36
# Greedy..............172/200_iter
# Found Loss 8.83e-02 at Jxy = 1.58, Jz = 2.15
# Greedy..............173/200_iter
# Found Loss 3.07e-01 at Jxy = 1.77, Jz = 1.60
# Greedy..............174/200_iter
# Found Loss 9.95e-01 at Jxy = 1.04, Jz = 1.63
# Greedy..............175/200_iter
# Found Loss 7.63e-01 at Jxy = 1.35, Jz = 0.92
# Greedy..............176/200_iter
# Found Loss 1.23e+00 at Jxy = 1.08, Jz = 1.14
# Greedy..............177/200_iter
# Found Loss 3.53e-01 at Jxy = 1.24, Jz = 0.99
# Greedy..............178/200_iter
# Found Loss 7.63e-01 at Jxy = 0.74, Jz = 2.09
# Greedy..............179/200_iter
# Found Loss -2.10e+00 at Jxy = -6.36, Jz = -2.33
# Greedy..............180/200_iter
# Found Loss 1.02e+00 at Jxy = 1.38, Jz = 1.23
# Greedy..............181/200_iter
# Found Loss 9.48e-01 at Jxy = 1.28, Jz = 1.46
# Random..............182/200_iter
# Found Loss -9.31e-01 at Jxy = -9.58, Jz = 9.70
# Greedy..............183/200_iter
# Found Loss 1.50e-01 at Jxy = 2.24, Jz = 0.86
# Random..............184/200_iter
# Found Loss -6.62e-01 at Jxy = 8.00, Jz = 0.35
# Greedy..............185/200_iter
# Found Loss 9.16e-01 at Jxy = 1.36, Jz = 1.46
# Greedy..............186/200_iter
# Found Loss 8.03e-01 at Jxy = 1.30, Jz = 1.68
# Greedy..............187/200_iter
# Found Loss 6.01e-01 at Jxy = 0.74, Jz = 1.55
# Greedy..............188/200_iter
# Found Loss -1.10e+00 at Jxy = -7.71, Jz = 6.66
# Greedy..............189/200_iter
# Found Loss -6.68e-01 at Jxy = -0.81, Jz = 6.41
# Greedy..............190/200_iter
# Found Loss 1.01e+00 at Jxy = 0.91, Jz = 1.66
# Greedy..............191/200_iter
# Found Loss -7.31e-01 at Jxy = 9.40, Jz = 1.37
# Greedy..............192/200_iter
# Found Loss 9.48e-01 at Jxy = 0.97, Jz = 1.95
# Greedy..............193/200_iter
# Found Loss 5.39e-01 at Jxy = 1.45, Jz = 1.77
# Greedy..............194/200_iter
# Found Loss 1.36e+00 at Jxy = 1.21, Jz = 1.37
# Greedy..............195/200_iter
# Found Loss 5.76e-01 at Jxy = 0.59, Jz = 1.69
# Greedy..............196/200_iter
# Found Loss -7.61e-01 at Jxy = 5.68, Jz = 8.05
# Greedy..............197/200_iter
# Found Loss 1.40e+00 at Jxy = 1.19, Jz = 1.41
# Greedy..............198/200_iter
# Found Loss 4.60e-01 at Jxy = 1.75, Jz = 1.03
# Greedy..............199/200_iter
# Found Loss 1.05e+00 at Jxy = 1.26, Jz = 1.55
# Greedy..............200/200_iter
# Found Loss -2.64e+00 at Jxy = 0.50, Jz = -5.73
# =======================COMPLETED=======================
#
#
#
# Best paramter find at Jxy = 1.01, Jz = 1.58, with loss = 1.63e+00

# %%
'{:.2e}'.format(evaluate_parameter(1.0, 1.5))
# Out:
# '1.66e+00'

# %% [markdown]
# ### Author's note:
# This demo is a proof-of-principle introduction to QMagen project.
#
# We plan to have a first release of this project in late-December.
